# %% [markdown]
# # Telco Churn — EDA + Baseline
#
# Notebook base listo. Próximo paso: cargar dataset y revisar nulos/tipos.

# %%
import pandas as pd
import numpy as np

# TODO: cuando descargues el dataset, ajusta la ruta:
# df = pd.read_csv('data/raw/telco_churn.csv')
# df.head()
print('OK: notebook base listo')
